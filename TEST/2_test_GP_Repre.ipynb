# %%
import numpy as np
grasp_data = np.load("./contact_points_merged.npy")

# %%
grasp_data.shape
# Out:
# (590, 3)

# %%
import open3d as o3d
import numpy as np

import gpytorch

import time
import torch
import itertools
import plotly.graph_objects as go
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
res = 100 # 150 # grid resolution # 50
k_nearest=5
display_percentile_low=10
display_percentile_high=90
training_iter = 200
grid_count = 10

# %%
temp_min = np.min(grasp_data, axis=0)
temp_max = np.max(grasp_data, axis=0)
fone   = np.ones((grasp_data.shape[0],)) 
min_data = temp_min - (temp_max-temp_min)*0.2 # We extend the boundaries of the object a bit to evaluate a little bit further 
max_data = temp_max + (temp_max-temp_min)*0.2


x_axis = np.linspace(min_data[0], max_data[0],grid_count)
y_axis = np.linspace(min_data[1], max_data[1],grid_count)
z_axis = np.linspace(min_data[2], max_data[2],grid_count)

# %%
train_X,train_y = [], []
for x in x_axis:
    for y in y_axis:
        for z in z_axis:
            train_X.append([x,y,z])
            train_y.append(0)

train_X = np.array(train_X)
train_y = np.array(train_y)

# %%
train_X.shape
# Out:
# (1000, 3)

# %%
train_y.shape
# Out:
# (1000,)

# %%
gridpcd = o3d.geometry.PointCloud()
gridpcd.points = o3d.utility.Vector3dVector(train_X)

kdtree_gridpcd = o3d.geometry.KDTreeFlann(gridpcd)

# %%
index = []

for p in grasp_data:
    [k, idx, dis_sqr] = kdtree_gridpcd.search_knn_vector_3d(p, k_nearest)
    for m in range(k):
        index.append(idx[m])

# %%
mask = np.ones(len(train_X), dtype=bool)
mask[index] = False
train_X = train_X[mask]
train_y = train_y[mask]

train_X = np.vstack([train_X, grasp_data])
train_y = np.hstack([train_y, fone])

# %%
train_X.shape
# Out:
# (1422, 3)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %%
x_axis
# Out:
# array([-0.19272414, -0.14769434, -0.10266454, -0.05763474, -0.01260494,
#         0.03242486,  0.07745466,  0.12248446,  0.16751425,  0.21254405])

# %%
xstar = np.zeros((res**3, 3))

for j in range(res):
	for i in range(res):
		d = j * res**2 # Delta
		axis_min = d + res * i
		axis_max = res * (i + 1) + d

		xstar[axis_min:axis_max, 0] = np.linspace(min_data[0], max_data[0], num=res) # in X
		xstar[axis_min:axis_max, 1] = min_data[1] + i * ((max_data[1] - min_data[1]) / res) # in X
		xstar[axis_min:axis_max, 2] = min_data[2] + ((j + 1) * ((max_data[2] - min_data[2]) / res))

tsize = res
xeva = np.reshape(xstar[:, 0], (tsize, tsize, tsize))
yeva = np.reshape(xstar[:, 1], (tsize, tsize, tsize))
zeva = np.reshape(xstar[:, 2], (tsize, tsize, tsize))

# %%
class ExactGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()
        #self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel())
        # self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RQKernel())
        self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel())
        # ThinPlateKernel
    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# %%
X = torch.FloatTensor(train_X).cuda()
y = torch.FloatTensor(train_y).cuda()

# %%
likelihood = gpytorch.likelihoods.GaussianLikelihood().cuda()
model =ExactGPModel(X,y,likelihood).cuda()
mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

model.train()
likelihood.train()
# Out:
# GaussianLikelihood(
#   (noise_covar): HomoskedasticNoise(
#     (raw_noise_constraint): GreaterThan(1.000E-04)
#   )
# )

# %%
print("Predicting")
start = time.time()
optimizer = torch.optim.Adam([
    {'params': model.parameters()},  # Includes GaussianLikelihood parameters
], lr=0.1)


for i in range(training_iter):
    # Zero gradients from previous iteration
    optimizer.zero_grad()
    # Output from model
    output = model(X)
    # Calc loss and backprop gradients
    loss = -mll(output, y)
    loss.backward()
    print('Iter %d/%d - Loss: %.3f   lengthscale: %.3f   noise: %.3f' % (
        i + 1, training_iter, loss.item(),
        model.covar_module.base_kernel.lengthscale.item(),
        model.likelihood.noise.item()
    ))
    optimizer.step()
# Out:
# Predicting
# Iter 1/200 - Loss: 0.878   lengthscale: 0.693   noise: 0.693
# Iter 2/200 - Loss: 0.846   lengthscale: 0.644   noise: 0.644
# Iter 3/200 - Loss: 0.810   lengthscale: 0.598   noise: 0.598
# Iter 4/200 - Loss: 0.768   lengthscale: 0.554   noise: 0.554
# Iter 5/200 - Loss: 0.726   lengthscale: 0.513   noise: 0.513
# Iter 6/200 - Loss: 0.687   lengthscale: 0.474   noise: 0.474
# Iter 7/200 - Loss: 0.649   lengthscale: 0.437   noise: 0.437
# Iter 8/200 - Loss: 0.613   lengthscale: 0.402   noise: 0.403
# Iter 9/200 - Loss: 0.576   lengthscale: 0.371   noise: 0.370
# Iter 10/200 - Loss: 0.543   lengthscale: 0.342   noise: 0.340
# Iter 11/200 - Loss: 0.502   lengthscale: 0.316   noise: 0.312
# Iter 12/200 - Loss: 0.468   lengthscale: 0.291   noise: 0.286
# Iter 13/200 - Loss: 0.430   lengthscale: 0.268   noise: 0.262
# Iter 14/200 - Loss: 0.387   lengthscale: 0.245   noise: 0.240
# Iter 15/200 - Loss: 0.343   lengthscale: 0.224   noise: 0.219
# Iter 16/200 - Loss: 0.303   lengthscale: 0.204   noise: 0.200
# Iter 17/200 - Loss: 0.257   lengthscale: 0.186   noise: 0.182
# Iter 18/200 - Loss: 0.221   lengthscale: 0.168   noise: 0.166
# Iter 19/200 - Loss: 0.177   lengthscale: 0.153   noise: 0.151
# Iter 20/200 - Loss: 0.136   lengthscale: 0.138   noise: 0.137
# Iter 21/200 - Loss: 0.102   lengthscale: 0.124   noise: 0.124
# Iter 22/200 - Loss: 0.075   lengthscale: 0.112   noise: 0.113
# Iter 23/200 - Loss: 0.057   lengthscale: 0.101   noise: 0.102
# Iter 24/200 - Loss: 0.019   lengthscale: 0.093   noise: 0.092
# Iter 25/200 - Loss: -0.008   lengthscale: 0.086   noise: 0.084
# Iter 26/200 - Loss: -0.028   lengthscale: 0.082   noise: 0.075
# Iter 27/200 - Loss: -0.063   lengthscale: 0.081   noise: 0.068
# Iter 28/200 - Loss: -0.101   lengthscale: 0.080   noise: 0.062
# Iter 29/200 - Loss: -0.122   lengthscale: 0.080   noise: 0.056
# Iter 30/200 - Loss: -0.156   lengthscale: 0.082   noise: 0.050
# Iter 31/200 - Loss: -0.189   lengthscale: 0.083   noise: 0.045
# Iter 32/200 - Loss: -0.216   lengthscale: 0.084   noise: 0.041
# Iter 33/200 - Loss: -0.247   lengthscale: 0.084   noise: 0.037
# Iter 34/200 - Loss: -0.286   lengthscale: 0.083   noise: 0.034
# Iter 35/200 - Loss: -0.291   lengthscale: 0.080   noise: 0.030
# Iter 36/200 - Loss: -0.326   lengthscale: 0.076   noise: 0.027
# Iter 37/200 - Loss: -0.327   lengthscale: 0.072   noise: 0.025
# Iter 38/200 - Loss: -0.357   lengthscale: 0.069   noise: 0.023
# Iter 39/200 - Loss: -0.371   lengthscale: 0.066   noise: 0.021
# Iter 40/200 - Loss: -0.411   lengthscale: 0.064   noise: 0.019
# Iter 41/200 - Loss: -0.402   lengthscale: 0.064   noise: 0.017
# Iter 42/200 - Loss: -0.436   lengthscale: 0.064   noise: 0.015
# Iter 43/200 - Loss: -0.493   lengthscale: 0.065   noise: 0.014
# Iter 44/200 - Loss: -0.522   lengthscale: 0.065   noise: 0.013
# Iter 45/200 - Loss: -0.566   lengthscale: 0.064   noise: 0.012
# Iter 46/200 - Loss: -0.582   lengthscale: 0.062   noise: 0.011
# Iter 47/200 - Loss: -0.601   lengthscale: 0.059   noise: 0.010
# Iter 48/200 - Loss: -0.627   lengthscale: 0.057   noise: 0.009
# Iter 49/200 - Loss: -0.627   lengthscale: 0.055   noise: 0.008
# Iter 50/200 - Loss: -0.646   lengthscale: 0.053   noise: 0.008
# Iter 51/200 - Loss: -0.671   lengthscale: 0.052   noise: 0.007
# Iter 52/200 - Loss: -0.730   lengthscale: 0.052   noise: 0.006
# Iter 53/200 - Loss: -0.743   lengthscale: 0.053   noise: 0.006
# Iter 54/200 - Loss: -0.769   lengthscale: 0.052   noise: 0.005
# Iter 55/200 - Loss: -0.815   lengthscale: 0.051   noise: 0.005
# Iter 56/200 - Loss: -0.864   lengthscale: 0.049   noise: 0.005
# Iter 57/200 - Loss: -0.869   lengthscale: 0.047   noise: 0.004
# Iter 58/200 - Loss: -0.911   lengthscale: 0.045   noise: 0.004
# Iter 59/200 - Loss: -0.892   lengthscale: 0.044   noise: 0.004
# Iter 60/200 - Loss: -0.948   lengthscale: 0.044   noise: 0.003
# Iter 61/200 - Loss: -0.973   lengthscale: 0.043   noise: 0.003
# Iter 62/200 - Loss: -1.010   lengthscale: 0.043   noise: 0.003
# Iter 63/200 - Loss: -1.020   lengthscale: 0.043   noise: 0.003
# Iter 64/200 - Loss: -1.036   lengthscale: 0.042   noise: 0.003
# Iter 65/200 - Loss: -1.066   lengthscale: 0.041   noise: 0.002
# Iter 66/200 - Loss: -1.078   lengthscale: 0.039   noise: 0.002
# Iter 67/200 - Loss: -1.093   lengthscale: 0.038   noise: 0.002
# Iter 68/200 - Loss: -1.102   lengthscale: 0.037   noise: 0.002
# Iter 69/200 - Loss: -1.107   lengthscale: 0.037   noise: 0.002
# Iter 70/200 - Loss: -1.123   lengthscale: 0.037   noise: 0.002
# Iter 71/200 - Loss: -1.120   lengthscale: 0.037   noise: 0.002
# Iter 72/200 - Loss: -1.142   lengthscale: 0.037   noise: 0.001
# Iter 73/200 - Loss: -1.152   lengthscale: 0.036   noise: 0.001
# Iter 74/200 - Loss: -1.162   lengthscale: 0.036   noise: 0.001
# Iter 75/200 - Loss: -1.162   lengthscale: 0.036   noise: 0.001
# Iter 76/200 - Loss: -1.169   lengthscale: 0.036   noise: 0.001
# Iter 77/200 - Loss: -1.175   lengthscale: 0.036   noise: 0.001
# Iter 78/200 - Loss: -1.166   lengthscale: 0.036   noise: 0.001
# Iter 79/200 - Loss: -1.172   lengthscale: 0.037   noise: 0.001
# Iter 80/200 - Loss: -1.195   lengthscale: 0.036   noise: 0.001
# Iter 81/200 - Loss: -1.190   lengthscale: 0.036   noise: 0.001
# Iter 82/200 - Loss: -1.177   lengthscale: 0.036   noise: 0.001
# Iter 83/200 - Loss: -1.186   lengthscale: 0.035   noise: 0.001
# Iter 84/200 - Loss: -1.172   lengthscale: 0.036   noise: 0.001
# Iter 85/200 - Loss: -1.170   lengthscale: 0.037   noise: 0.001
# Iter 86/200 - Loss: -1.190   lengthscale: 0.037   noise: 0.001
# Iter 87/200 - Loss: -1.175   lengthscale: 0.037   noise: 0.001
# Iter 88/200 - Loss: -1.181   lengthscale: 0.036   noise: 0.001
# Iter 89/200 - Loss: -1.165   lengthscale: 0.036   noise: 0.001
# Iter 90/200 - Loss: -1.188   lengthscale: 0.036   noise: 0.001
# Iter 91/200 - Loss: -1.161   lengthscale: 0.036   noise: 0.001
# Iter 92/200 - Loss: -1.211   lengthscale: 0.036   noise: 0.001
# Iter 93/200 - Loss: -1.206   lengthscale: 0.036   noise: 0.001
# Iter 94/200 - Loss: -1.193   lengthscale: 0.036   noise: 0.000
# Iter 95/200 - Loss: -1.219   lengthscale: 0.035   noise: 0.000
# Iter 96/200 - Loss: -1.194   lengthscale: 0.035   noise: 0.000
# Iter 97/200 - Loss: -1.216   lengthscale: 0.035   noise: 0.000
# Iter 98/200 - Loss: -1.233   lengthscale: 0.035   noise: 0.000
# Iter 99/200 - Loss: -1.235   lengthscale: 0.035   noise: 0.000
# Iter 100/200 - Loss: -1.222   lengthscale: 0.035   noise: 0.000
# Iter 101/200 - Loss: -1.230   lengthscale: 0.034   noise: 0.000
# Iter 102/200 - Loss: -1.246   lengthscale: 0.034   noise: 0.000
# Iter 103/200 - Loss: -1.215   lengthscale: 0.034   noise: 0.000
# Iter 104/200 - Loss: -1.249   lengthscale: 0.034   noise: 0.000
# Iter 105/200 - Loss: -1.217   lengthscale: 0.034   noise: 0.000
# Iter 106/200 - Loss: -1.249   lengthscale: 0.034   noise: 0.000
# Iter 107/200 - Loss: -1.231   lengthscale: 0.034   noise: 0.000
# Iter 108/200 - Loss: -1.247   lengthscale: 0.034   noise: 0.000
# Iter 109/200 - Loss: -1.244   lengthscale: 0.034   noise: 0.000
# Iter 110/200 - Loss: -1.225   lengthscale: 0.034   noise: 0.000
# Iter 111/200 - Loss: -1.265   lengthscale: 0.034   noise: 0.000
# Iter 112/200 - Loss: -1.228   lengthscale: 0.034   noise: 0.000
# Iter 113/200 - Loss: -1.224   lengthscale: 0.034   noise: 0.000
# Iter 114/200 - Loss: -1.229   lengthscale: 0.034   noise: 0.000
# Iter 115/200 - Loss: -1.227   lengthscale: 0.034   noise: 0.000
# Iter 116/200 - Loss: -1.231   lengthscale: 0.034   noise: 0.000
# Iter 117/200 - Loss: -1.235   lengthscale: 0.034   noise: 0.000
# Iter 118/200 - Loss: -1.234   lengthscale: 0.034   noise: 0.000
# Iter 119/200 - Loss: -1.207   lengthscale: 0.034   noise: 0.000
# Iter 120/200 - Loss: -1.224   lengthscale: 0.034   noise: 0.000
# Iter 121/200 - Loss: -1.268   lengthscale: 0.033   noise: 0.000
# Iter 122/200 - Loss: -1.269   lengthscale: 0.033   noise: 0.000
# Iter 123/200 - Loss: -1.238   lengthscale: 0.034   noise: 0.000
# Iter 124/200 - Loss: -1.243   lengthscale: 0.034   noise: 0.000
# Iter 125/200 - Loss: -1.232   lengthscale: 0.034   noise: 0.000
# Iter 126/200 - Loss: -1.241   lengthscale: 0.033   noise: 0.000
# Iter 127/200 - Loss: -1.227   lengthscale: 0.033   noise: 0.000
# Iter 128/200 - Loss: -1.237   lengthscale: 0.033   noise: 0.000
# Iter 129/200 - Loss: -1.244   lengthscale: 0.034   noise: 0.000
# Iter 130/200 - Loss: -1.235   lengthscale: 0.034   noise: 0.000
# Iter 131/200 - Loss: -1.239   lengthscale: 0.034   noise: 0.000
# Iter 132/200 - Loss: -1.266   lengthscale: 0.033   noise: 0.000
# Iter 133/200 - Loss: -1.226   lengthscale: 0.033   noise: 0.000
# Iter 134/200 - Loss: -1.215   lengthscale: 0.033   noise: 0.000
# Iter 135/200 - Loss: -1.254   lengthscale: 0.034   noise: 0.000
# Iter 136/200 - Loss: -1.207   lengthscale: 0.034   noise: 0.000
# Iter 137/200 - Loss: -1.239   lengthscale: 0.034   noise: 0.000
# Iter 138/200 - Loss: -1.229   lengthscale: 0.034   noise: 0.000
# Iter 139/200 - Loss: -1.229   lengthscale: 0.034   noise: 0.000
# Iter 140/200 - Loss: -1.205   lengthscale: 0.034   noise: 0.000
# Iter 141/200 - Loss: -1.238   lengthscale: 0.033   noise: 0.000
# Iter 142/200 - Loss: -1.241   lengthscale: 0.033   noise: 0.000
# Iter 143/200 - Loss: -1.248   lengthscale: 0.033   noise: 0.000
# Iter 144/200 - Loss: -1.254   lengthscale: 0.033   noise: 0.000
# Iter 145/200 - Loss: -1.245   lengthscale: 0.033   noise: 0.000
# Iter 146/200 - Loss: -1.234   lengthscale: 0.033   noise: 0.000
# Iter 147/200 - Loss: -1.226   lengthscale: 0.033   noise: 0.000
# Iter 148/200 - Loss: -1.248   lengthscale: 0.033   noise: 0.000
# Iter 149/200 - Loss: -1.250   lengthscale: 0.033   noise: 0.000
# Iter 150/200 - Loss: -1.260   lengthscale: 0.033   noise: 0.000
# Iter 151/200 - Loss: -1.212   lengthscale: 0.033   noise: 0.000
# Iter 152/200 - Loss: -1.206   lengthscale: 0.033   noise: 0.000
# Iter 153/200 - Loss: -1.211   lengthscale: 0.033   noise: 0.000
# Iter 154/200 - Loss: -1.238   lengthscale: 0.034   noise: 0.000
# Iter 155/200 - Loss: -1.244   lengthscale: 0.034   noise: 0.000
# Iter 156/200 - Loss: -1.219   lengthscale: 0.033   noise: 0.000
# Iter 157/200 - Loss: -1.240   lengthscale: 0.033   noise: 0.000
# Iter 158/200 - Loss: -1.256   lengthscale: 0.033   noise: 0.000
# Iter 159/200 - Loss: -1.254   lengthscale: 0.033   noise: 0.000
# Iter 160/200 - Loss: -1.232   lengthscale: 0.034   noise: 0.000
# Iter 161/200 - Loss: -1.229   lengthscale: 0.034   noise: 0.000
# Iter 162/200 - Loss: -1.218   lengthscale: 0.033   noise: 0.000
# Iter 163/200 - Loss: -1.257   lengthscale: 0.033   noise: 0.000
# Iter 164/200 - Loss: -1.201   lengthscale: 0.033   noise: 0.000
# Iter 165/200 - Loss: -1.230   lengthscale: 0.033   noise: 0.000
# Iter 166/200 - Loss: -1.227   lengthscale: 0.033   noise: 0.000
# Iter 167/200 - Loss: -1.223   lengthscale: 0.033   noise: 0.000
# Iter 168/200 - Loss: -1.250   lengthscale: 0.033   noise: 0.000
# Iter 169/200 - Loss: -1.249   lengthscale: 0.033   noise: 0.000
# Iter 170/200 - Loss: -1.235   lengthscale: 0.033   noise: 0.000
# Iter 171/200 - Loss: -1.258   lengthscale: 0.034   noise: 0.000
# Iter 172/200 - Loss: -1.235   lengthscale: 0.033   noise: 0.000
# Iter 173/200 - Loss: -1.240   lengthscale: 0.033   noise: 0.000
# Iter 174/200 - Loss: -1.254   lengthscale: 0.033   noise: 0.000
# Iter 175/200 - Loss: -1.232   lengthscale: 0.033   noise: 0.000
# Iter 176/200 - Loss: -1.230   lengthscale: 0.034   noise: 0.000
# Iter 177/200 - Loss: -1.246   lengthscale: 0.034   noise: 0.000
# Iter 178/200 - Loss: -1.243   lengthscale: 0.034   noise: 0.000
# Iter 179/200 - Loss: -1.228   lengthscale: 0.033   noise: 0.000
# Iter 180/200 - Loss: -1.208   lengthscale: 0.033   noise: 0.000
# Iter 181/200 - Loss: -1.233   lengthscale: 0.033   noise: 0.000
# Iter 182/200 - Loss: -1.247   lengthscale: 0.034   noise: 0.000
# Iter 183/200 - Loss: -1.200   lengthscale: 0.034   noise: 0.000
# Iter 184/200 - Loss: -1.255   lengthscale: 0.033   noise: 0.000
# Iter 185/200 - Loss: -1.243   lengthscale: 0.033   noise: 0.000
# Iter 186/200 - Loss: -1.247   lengthscale: 0.033   noise: 0.000
# Iter 187/200 - Loss: -1.237   lengthscale: 0.033   noise: 0.000
# Iter 188/200 - Loss: -1.235   lengthscale: 0.033   noise: 0.000
# Iter 189/200 - Loss: -1.235   lengthscale: 0.033   noise: 0.000
# Iter 190/200 - Loss: -1.244   lengthscale: 0.033   noise: 0.000
# Iter 191/200 - Loss: -1.240   lengthscale: 0.033   noise: 0.000
# Iter 192/200 - Loss: -1.225   lengthscale: 0.033   noise: 0.000
# Iter 193/200 - Loss: -1.245   lengthscale: 0.033   noise: 0.000
# Iter 194/200 - Loss: -1.231   lengthscale: 0.033   noise: 0.000
# Iter 195/200 - Loss: -1.221   lengthscale: 0.033   noise: 0.000
# Iter 196/200 - Loss: -1.235   lengthscale: 0.033   noise: 0.000
# Iter 197/200 - Loss: -1.231   lengthscale: 0.033   noise: 0.000
# Iter 198/200 - Loss: -1.215   lengthscale: 0.033   noise: 0.000
# Iter 199/200 - Loss: -1.218   lengthscale: 0.033   noise: 0.000
# Iter 200/200 - Loss: -1.235   lengthscale: 0.033   noise: 0.000

# %%
model.eval()
likelihood.eval()
# Out:
# GaussianLikelihood(
#   (noise_covar): HomoskedasticNoise(
#     (raw_noise_constraint): GreaterThan(1.000E-04)
#   )
# )

# %%
with torch.no_grad(), gpytorch.settings.fast_pred_var():
    x = torch.FloatTensor(grasp_data).cuda()
    observed_pred = likelihood(model(x))
    original_prediction = observed_pred.mean.cpu().numpy()
    # print(pred.shape)
    original_confidence_lower, original_confidence_upper = observed_pred.confidence_region()

original_pred_low, original_pred_high = np.percentile(original_prediction, [display_percentile_low, display_percentile_high])

# %%
original_pred_low
# Out:
# 0.9920201897621155

# %%
original_pred_high
# Out:
# 1.0074458599090577

# %%
_ = time.time()
prediction_buf = []
uncertainty_buf = []
isplit=0
step_length = 10000
with torch.no_grad(), gpytorch.settings.fast_pred_var():
    # test_x = torch.linspace(0, 1, 51)
    while isplit*step_length<xstar.shape[0]:
        isplit += 1
        split_min = step_length * (isplit-1)
        split_max = np.minimum(step_length * isplit, xstar.shape[0])

        xstar_tensor = torch.FloatTensor(xstar[split_min:split_max,:]).cuda()
        observed_pred = likelihood(model(xstar_tensor))
        prediction = observed_pred.mean.cpu().numpy()
        prediction_buf.append(prediction)
        confidence_lower, confidence_upper = observed_pred.confidence_region()
        confidence_lower = confidence_lower.cpu().numpy()
        confidence_upper = confidence_upper.cpu().numpy()
        uncertainty_buf.append(confidence_upper - confidence_lower)

# %%
prediction = np.hstack(prediction_buf)
uncertainty = np.hstack(uncertainty_buf)

# %%
prediction
# Out:
# array([-0.00996504, -0.01253034, -0.01430809, ..., -0.00672872,
#        -0.00530795, -0.00312985], dtype=float32)

# %%
uncertainty
# Out:
# array([0.7974646 , 0.79237753, 0.7880502 , ..., 0.80020595, 0.8047056 ,
#        0.8095431 ], dtype=float32)

# %%
print("plotting")


fig = go.Figure(data=
            [go.Isosurface(
                x=xeva.flatten(),
                y=yeva.flatten(),
                z=zeva.flatten(),
                value=prediction.flatten(),
                isomin=original_pred_low,#-np.std(xtrain_prediction)/4 + np.mean(xtrain_prediction),
                isomax=original_pred_high,#np.std(xtrain_prediction)/4 + np.mean(xtrain_prediction), #right for bunny model
                caps=dict(x_show=False, y_show=False),
                # colorscale='RdBu',
                surface= dict(show=True,count=2, fill=0.6),

            ),
            go.Scatter3d(
                x=grasp_data[:,0],
                y=grasp_data[:,1],
                z=grasp_data[:,2],
                mode='markers',
                marker=dict(color="red")
            ),
            ]
    )
fig.show()
